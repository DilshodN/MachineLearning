# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder

from sklearn.ensemble import RandomForestRegressor

import xgboost
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
import catboost

# %%
def show_results(preds, gt):
    rmse =  np.sqrt(mean_squared_error(preds, gt))
    print('RMSE:', rmse)
    return rmse

# %%
ds = pd.read_csv("train.csv")

# %%
best_scores = {}

# %%
def get_nan_stat_table(dataset):
    total = dataset.isnull().sum().sort_values(ascending=False)

    percent = total / len(dataset) * 100
    nan_stat_tbl = pd.concat([total, percent], axis=1, keys=['Total', '%'])
    return nan_stat_tbl.loc[(nan_stat_tbl['%']>0)]

get_nan_stat_table(ds[cat_features])
# Out:
#               Total          %
# PoolQC         1453  99.520548
# MiscFeature    1406  96.301370
# Alley          1369  93.767123
# Fence          1179  80.753425
# FireplaceQu     690  47.260274
# GarageType       81   5.547945
# GarageCond       81   5.547945
# GarageQual       81   5.547945
# GarageFinish     81   5.547945
# BsmtFinType2     38   2.602740
# BsmtExposure     38   2.602740
# BsmtFinType1     37   2.534247
# BsmtQual         37   2.534247
# BsmtCond         37   2.534247
# MasVnrType        8   0.547945
# Electrical        1   0.068493

# %%
def prepare_dataset(dataset):
    ds_new = dataset.drop(columns=["Id"])

    cat_features = ds_new.select_dtypes(include = ["object"]).columns
    num_features = ds_new.select_dtypes(exclude = ["object"]).columns

    ds_new[cat_features] = ds_new[cat_features].fillna('None')

    for feature in num_features:
        ds_new[feature] = ds_new[feature].fillna(ds_new[feature].mean())

    return ds_new

# %%
ds = prepare_dataset(ds)

ds_nocat = ds.copy()

for feature in cat_features:
    encoder = LabelEncoder()
    encoded_feature = encoder.fit_transform(ds[feature])
    ds_nocat[feature] = encoded_feature

# %%
y = np.log1p(ds.SalePrice.to_numpy())
x = ds_nocat.drop(columns=["SalePrice"]).to_numpy()

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=98987)

# %%
x.shape,y.shape
# Out:
# ((1460, 79), (1460,))

# %%
parameters = {
    'criterion':('squared_error',), 
    'max_depth': (1000,),
    'max_features':(1/3, ),
    'n_estimators': (100, 1000),
    'min_samples_leaf': (1, 2, 8)
}

rforest = RandomForestRegressor()
rforest_gs = GridSearchCV(rforest, parameters, verbose=2)
rforest_gs.fit(x_train, y_train);
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=1, n_estimators=100; total time=   1.1s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=1, n_estimators=100; total time=   0.9s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=1, n_estimators=100; total time=   0.9s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=1, n_estimators=100; total time=   1.2s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=1, n_estimators=100; total time=   1.2s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=1, n_estimators=1000; total time=  11.5s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=1, n_estimators=1000; total time=  11.1s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=1, n_estimators=1000; total time=   9.3s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=1, n_estimators=1000; total time=  12.6s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=1, n_estimators=1000; total time=  10.0s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=2, n_estimators=100; total time=   0.8s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=2, n_estimators=100; total time=   0.9s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=2, n_estimators=100; total time=   0.9s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=2, n_estimators=100; total time=   0.9s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=2, n_estimators=100; total time=   0.9s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=2, n_estimators=1000; total time=  13.0s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=2, n_estimators=1000; total time=  19.2s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=2, n_estimators=1000; total time=  12.7s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=2, n_estimators=1000; total time=  13.6s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=2, n_estimators=1000; total time=  13.0s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=8, n_estimators=100; total time=   1.5s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=8, n_estimators=100; total time=   0.9s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=8, n_estimators=100; total time=   1.2s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=8, n_estimators=100; total time=   0.9s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=8, n_estimators=100; total time=   0.7s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=8, n_estimators=1000; total time=  10.3s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=8, n_estimators=1000; total time=   7.2s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=8, n_estimators=1000; total time=   8.3s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=8, n_estimators=1000; total time=   9.5s
# [CV] END criterion=squared_error, max_depth=1000, max_features=0.3333333333333333, min_samples_leaf=8, n_estimators=1000; total time=   9.4s

# %%
print(rforest_gs.best_params_)
best_scores["RandomForest"] = show_results(rforest_gs.predict(x_test), y_test)
# Out:
# {'criterion': 'squared_error', 'max_depth': 1000, 'max_features': 0.3333333333333333, 'min_samples_leaf': 1, 'n_estimators': 1000}
# RMSE: 0.15588079024545187

# %%
parameters = {
    "learning_rate": (0.001, 0.01, ),
    "max_depth": [ 2, 4],
    "min_child_weight": [ 1, 10],
    "gamma":[ 0.0,],
    "n_estimators": [1000, 5000]
}
xgb = xgboost.XGBRegressor()
xgb_gs = GridSearchCV(xgb, parameters, verbose=2, cv=3)
xgb_gs.fit(x_train, y_train);
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [CV] END gamma=0.0, learning_rate=0.001, max_depth=2, min_child_weight=1, n_estimators=1000; total time=   2.0s
# [CV] END gamma=0.0, learning_rate=0.001, max_depth=2, min_child_weight=1, n_estimators=1000; total time=   1.5s
# [CV] END gamma=0.0, learning_rate=0.001, max_depth=2, min_child_weight=1, n_estimators=1000; total time=   1.5s
# [CV] END gamma=0.0, learning_rate=0.001, max_depth=2, min_child_weight=1, n_estimators=5000; total time=  12.4s
# [CV] END gamma=0.0, learning_rate=0.001, max_depth=2, min_child_weight=1, n_estimators=5000; total time=   8.6s
# [CV] END gamma=0.0, learning_rate=0.001, max_depth=2, min_child_weight=1, n_estimators=5000; total time=   9.2s
# [CV] END gamma=0.0, learning_rate=0.001, max_depth=2, min_child_weight=10, n_estimators=1000; total time=   1.5s
# [CV] END gamma=0.0, learning_rate=0.001, max_depth=2, min_child_weight=10, n_estimators=1000; total time=   1.5s
# [CV] END gamma=0.0, learning_rate=0.001, max_depth=2, min_child_weight=10, n_estimators=1000; total time=   1.6s
# [CV] END gamma=0.0, learning_rate=0.001, max_depth=2, min_child_weight=10, n_estimators=5000; total time=  10.7s
# [CV] END gamma=0.0, learning_rate=0.001, max_depth=2, min_child_weight=10, n_estimators=5000; total time=   8.8s
# [CV] END gamma=0.0, learning_rate=0.001, max_depth=2, min_child_weight=10, n_estimators=5000; total time=   9.5s
# [CV] END gamma=0.0, learning_rate=0.001, max_depth=4, min_child_weight=1, n_estimators=1000; total time=   1.6s
# [CV] END gamma=0.0, learning_rate=0.001, max_depth=4, min_child_weight=1, n_estimators=1000; total time=   1.8s
# [CV] END gamma=0.0, learning_rate=0.001, max_depth=4, min_child_weight=1, n_estimators=1000; total time=   2.5s
# [CV] END gamma=0.0, learning_rate=0.001, max_depth=4, min_child_weight=1, n_estimators=5000; total time=  30.8s
# [CV] END gamma=0.0, learning_rate=0.001, max_depth=4, min_child_weight=1, n_estimators=5000; total time=  22.6s
# [CV] END gamma=0.0, learning_rate=0.001, max_depth=4, min_child_weight=1, n_estimators=5000; total time=  22.5s
# [CV] END gamma=0.0, learning_rate=0.001, max_depth=4, min_child_weight=10, n_estimators=1000; total time=   1.9s
# [CV] END gamma=0.0, learning_rate=0.001, max_depth=4, min_child_weight=10, n_estimators=1000; total time=   2.3s
# [CV] END gamma=0.0, learning_rate=0.001, max_depth=4, min_child_weight=10, n_estimators=1000; total time=   2.4s
# [CV] END gamma=0.0, learning_rate=0.001, max_depth=4, min_child_weight=10, n_estimators=5000; total time=  16.1s
# [CV] END gamma=0.0, learning_rate=0.001, max_depth=4, min_child_weight=10, n_estimators=5000; total time=  16.1s
# [CV] END gamma=0.0, learning_rate=0.001, max_depth=4, min_child_weight=10, n_estimators=5000; total time=  18.4s
# [CV] END gamma=0.0, learning_rate=0.01, max_depth=2, min_child_weight=1, n_estimators=1000; total time=   1.8s
# [CV] END gamma=0.0, learning_rate=0.01, max_depth=2, min_child_weight=1, n_estimators=1000; total time=   1.8s
# [CV] END gamma=0.0, learning_rate=0.01, max_depth=2, min_child_weight=1, n_estimators=1000; total time=   3.2s
# [CV] END gamma=0.0, learning_rate=0.01, max_depth=2, min_child_weight=1, n_estimators=5000; total time=  11.9s
# [CV] END gamma=0.0, learning_rate=0.01, max_depth=2, min_child_weight=1, n_estimators=5000; total time=  24.8s
# [CV] END gamma=0.0, learning_rate=0.01, max_depth=2, min_child_weight=1, n_estimators=5000; total time=  25.6s
# [CV] END gamma=0.0, learning_rate=0.01, max_depth=2, min_child_weight=10, n_estimators=1000; total time=   3.3s
# [CV] END gamma=0.0, learning_rate=0.01, max_depth=2, min_child_weight=10, n_estimators=1000; total time=   2.1s
# [CV] END gamma=0.0, learning_rate=0.01, max_depth=2, min_child_weight=10, n_estimators=1000; total time=   1.8s
# [CV] END gamma=0.0, learning_rate=0.01, max_depth=2, min_child_weight=10, n_estimators=5000; total time=   9.1s
# [CV] END gamma=0.0, learning_rate=0.01, max_depth=2, min_child_weight=10, n_estimators=5000; total time=   9.3s
# [CV] END gamma=0.0, learning_rate=0.01, max_depth=2, min_child_weight=10, n_estimators=5000; total time=  18.2s
# [CV] END gamma=0.0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000; total time=   9.2s
# [CV] END gamma=0.0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000; total time=   5.1s
# [CV] END gamma=0.0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=1000; total time=   4.7s
# [CV] END gamma=0.0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=5000; total time=  24.8s
# [CV] END gamma=0.0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=5000; total time=  34.6s
# [CV] END gamma=0.0, learning_rate=0.01, max_depth=4, min_child_weight=1, n_estimators=5000; total time=  30.5s
# [CV] END gamma=0.0, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=1000; total time=   5.9s
# [CV] END gamma=0.0, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=1000; total time=   4.7s
# [CV] END gamma=0.0, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=1000; total time=   4.8s
# [CV] END gamma=0.0, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=5000; total time=  47.2s
# [CV] END gamma=0.0, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=5000; total time= 1.1min
# [CV] END gamma=0.0, learning_rate=0.01, max_depth=4, min_child_weight=10, n_estimators=5000; total time=  35.2s

# %%
print(xgb_gs.best_params_)
best_scores["XGBoost"] = show_results(xgb_gs.predict(x_test), y_test)
# Out:
# {'gamma': 0.0, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 1, 'n_estimators': 5000}
# RMSE: 0.12792625107811667

# %%
parameters = {
    'num_leaves': (40, 20, 10,),
    'learning_rate': (0.1, 0.01, 0.05),
    'max_depth': (-1,),
    'n_estimators': (10**3, 10**4),}

lgbmr_gs = GridSearchCV(LGBMRegressor(), parameters, verbose=2)
lgbmr_gs.fit(x_train, y_train);
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=1000, num_leaves=40; total time=   4.8s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=1000, num_leaves=40; total time=   3.9s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=1000, num_leaves=40; total time=   3.8s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=1000, num_leaves=40; total time=   4.6s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=1000, num_leaves=40; total time=   5.4s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=1000, num_leaves=20; total time=   3.3s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=1000, num_leaves=20; total time=   2.7s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=1000, num_leaves=20; total time=   2.2s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=1000, num_leaves=20; total time=   2.4s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=1000, num_leaves=20; total time=   2.4s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=1000, num_leaves=10; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=1000, num_leaves=10; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=1000, num_leaves=10; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=1000, num_leaves=10; total time=   1.3s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=1000, num_leaves=10; total time=   1.4s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=10000, num_leaves=40; total time=  48.1s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=10000, num_leaves=40; total time= 2.4min
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=10000, num_leaves=40; total time= 2.9min
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=10000, num_leaves=40; total time= 1.4min
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=10000, num_leaves=40; total time=  56.5s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=10000, num_leaves=20; total time=  30.0s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=10000, num_leaves=20; total time= 1.2min
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=10000, num_leaves=20; total time=  23.9s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=10000, num_leaves=20; total time=  24.5s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=10000, num_leaves=20; total time=  26.0s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=10000, num_leaves=10; total time=  17.1s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=10000, num_leaves=10; total time=  15.6s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=10000, num_leaves=10; total time=  17.8s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=10000, num_leaves=10; total time=  15.9s
# [CV] END learning_rate=0.1, max_depth=-1, n_estimators=10000, num_leaves=10; total time=  37.1s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=1000, num_leaves=40; total time=  13.5s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=1000, num_leaves=40; total time=   5.7s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=1000, num_leaves=40; total time=   4.4s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=1000, num_leaves=40; total time=   4.7s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=1000, num_leaves=40; total time=   4.8s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=1000, num_leaves=20; total time=   2.7s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=1000, num_leaves=20; total time=   2.9s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=1000, num_leaves=20; total time=   2.7s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=1000, num_leaves=20; total time=   3.8s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=1000, num_leaves=20; total time=   2.6s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=1000, num_leaves=10; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=1000, num_leaves=10; total time=   1.9s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=1000, num_leaves=10; total time=   2.0s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=1000, num_leaves=10; total time=   1.5s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=1000, num_leaves=10; total time=   3.6s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=10000, num_leaves=40; total time=  56.9s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=10000, num_leaves=40; total time=  52.9s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=10000, num_leaves=40; total time= 1.0min
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=10000, num_leaves=40; total time= 1.5min
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=10000, num_leaves=40; total time= 1.4min
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=10000, num_leaves=20; total time=  47.3s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=10000, num_leaves=20; total time= 1.7min
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=10000, num_leaves=20; total time=  45.1s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=10000, num_leaves=20; total time= 1.1min
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=10000, num_leaves=20; total time=  44.0s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=10000, num_leaves=10; total time=  14.6s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=10000, num_leaves=10; total time=  46.7s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=10000, num_leaves=10; total time=  47.5s
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=10000, num_leaves=10; total time= 3.0min
# [CV] END learning_rate=0.01, max_depth=-1, n_estimators=10000, num_leaves=10; total time= 1.9min
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=1000, num_leaves=40; total time=  26.7s
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=1000, num_leaves=40; total time=  20.1s
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=1000, num_leaves=40; total time=   8.5s
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=1000, num_leaves=40; total time=   9.1s
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=1000, num_leaves=40; total time=   9.6s
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=1000, num_leaves=20; total time=   4.1s
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=1000, num_leaves=20; total time=   4.8s
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=1000, num_leaves=20; total time=   4.6s
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=1000, num_leaves=20; total time=   3.9s
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=1000, num_leaves=20; total time=   4.0s
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=1000, num_leaves=10; total time=   2.2s
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=1000, num_leaves=10; total time=   1.9s
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=1000, num_leaves=10; total time=   2.9s
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=1000, num_leaves=10; total time=   2.9s
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=1000, num_leaves=10; total time=   3.4s
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=10000, num_leaves=40; total time= 3.3min
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=10000, num_leaves=40; total time= 2.8min
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=10000, num_leaves=40; total time= 3.7min
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=10000, num_leaves=40; total time= 2.3min
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=10000, num_leaves=40; total time= 2.0min
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=10000, num_leaves=20; total time=  14.9s
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=10000, num_leaves=20; total time=30.3min
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=10000, num_leaves=20; total time=  16.8s
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=10000, num_leaves=20; total time=  12.1s
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=10000, num_leaves=20; total time=15.9min
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=10000, num_leaves=10; total time=  13.1s
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=10000, num_leaves=10; total time=   6.7s
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=10000, num_leaves=10; total time=   6.7s
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=10000, num_leaves=10; total time=   6.8s
# [CV] END learning_rate=0.05, max_depth=-1, n_estimators=10000, num_leaves=10; total time=   7.8s

# %%
print(lgbmr_gs.best_params_)
best_scores["LightGBM"] = show_results(lgbmr_gs.predict(x_test), y_test)
# Out:
# {'learning_rate': 0.05, 'max_depth': -1, 'n_estimators': 1000, 'num_leaves': 10}
# RMSE: 0.14171984107096894

# %%
# logloss: gt * log(pred) + (1 - gt) * log(1 - pred)

# 1 * log(0.95) = 

# 1) wth is margin

# 2)

# %%
ds = pd.read_csv("train.csv")

ds.drop(columns=["Id"], inplace=True)
x = ds.drop(columns=['SalePrice'])
y = np.log1p(ds['SalePrice'])

cat_features = ds.select_dtypes(include = ["object"]).columns

x[cat_features] = x[cat_features].fillna('None')

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=98987)

# %%
train_pool = catboost.Pool(x_train, y_train, cat_features=cat_features.tolist())
test_pool = catboost.Pool(x_test, y_test, cat_features=cat_features.tolist())

# %%
p_grid = {
        'learning_rate': [0.07, 0.9],
        'depth': [1, 2, 3],
        'l2_leaf_reg': [0.7, 1, 1.3],
}

catboost_cls = CatBoostRegressor(
        loss_function='RMSE',
        verbose=0
)
grid_search_results = catboost_cls.grid_search(p_grid, train_pool, shuffle=False, verbose=1, search_by_train_test_split=False)
# Out:
# Training on fold [0/3]
#
# bestTest = 0.1424761025
# bestIteration = 918
#
# Training on fold [1/3]
#
# bestTest = 0.1225894164
# bestIteration = 999
#
# Training on fold [2/3]
#
# bestTest = 0.1422752513
# bestIteration = 392
#
# 0:	loss: 0.1363115	best: 0.1363115 (0)	total: 4.09s	remaining: 1m 9s
# Training on fold [0/3]
#
# bestTest = 0.1452043185
# bestIteration = 890
#
# Training on fold [1/3]
#
# bestTest = 0.1288349456
# bestIteration = 420
#
# Training on fold [2/3]
#
# bestTest = 0.1584301759
# bestIteration = 804
#
# 1:	loss: 0.1455148	best: 0.1363115 (0)	total: 10.2s	remaining: 1m 21s
# Training on fold [0/3]
#
# bestTest = 0.1422212522
# bestIteration = 955
#
# Training on fold [1/3]
#
# bestTest = 0.1221175133
# bestIteration = 999
#
# Training on fold [2/3]
#
# bestTest = 0.1427051403
# bestIteration = 468
#
# 2:	loss: 0.1360531	best: 0.1360531 (2)	total: 16.6s	remaining: 1m 23s
# Training on fold [0/3]
#
# bestTest = 0.1485506428
# bestIteration = 979
#
# Training on fold [1/3]
#
# bestTest = 0.1267461794
# bestIteration = 469
#
# Training on fold [2/3]
#
# bestTest = 0.1582160991
# bestIteration = 357
#
# 3:	loss: 0.1455025	best: 0.1360531 (2)	total: 21.6s	remaining: 1m 15s
# Training on fold [0/3]
#
# bestTest = 0.143346303
# bestIteration = 976
#
# Training on fold [1/3]
#
# bestTest = 0.1224126853
# bestIteration = 998
#
# Training on fold [2/3]
#
# bestTest = 0.1431360024
# bestIteration = 516
#
# 4:	loss: 0.1366444	best: 0.1360531 (2)	total: 25.9s	remaining: 1m 7s
# Training on fold [0/3]
#
# bestTest = 0.1500051228
# bestIteration = 548
#
# Training on fold [1/3]
#
# bestTest = 0.1294807427
# bestIteration = 611
#
# Training on fold [2/3]
#
# bestTest = 0.1496625098
# bestIteration = 390
#
# 5:	loss: 0.1452158	best: 0.1360531 (2)	total: 29.7s	remaining: 59.5s
# Training on fold [0/3]
#
# bestTest = 0.1395253855
# bestIteration = 964
#
# Training on fold [1/3]
#
# bestTest = 0.1263578394
# bestIteration = 741
#
# Training on fold [2/3]
#
# bestTest = 0.133910422
# bestIteration = 864
#
# 6:	loss: 0.1335618	best: 0.1335618 (6)	total: 48.9s	remaining: 1m 16s
# Training on fold [0/3]
#
# bestTest = 0.1682787555
# bestIteration = 944
#
# Training on fold [1/3]
#
# bestTest = 0.1541485653
# bestIteration = 112
#
# Training on fold [2/3]
#
# bestTest = 0.1588957725
# bestIteration = 109
#
# 7:	loss: 0.1692081	best: 0.1335618 (6)	total: 1m 1s	remaining: 1m 17s
# Training on fold [0/3]
#
# bestTest = 0.1384342603
# bestIteration = 999
#
# Training on fold [1/3]
#
# bestTest = 0.1263498987
# bestIteration = 980
#
# Training on fold [2/3]
#
# bestTest = 0.1331382242
# bestIteration = 954
#
# 8:	loss: 0.1328640	best: 0.1328640 (8)	total: 1m 12s	remaining: 1m 12s
# Training on fold [0/3]
#
# bestTest = 0.1623707065
# bestIteration = 189
#
# Training on fold [1/3]
#
# bestTest = 0.151231797
# bestIteration = 242
#
# Training on fold [2/3]
#
# bestTest = 0.1666628169
# bestIteration = 58
#
# 9:	loss: 0.1655148	best: 0.1328640 (8)	total: 1m 26s	remaining: 1m 9s
# Training on fold [0/3]
#
# bestTest = 0.1411386357
# bestIteration = 974
#
# Training on fold [1/3]
#
# bestTest = 0.1244673058
# bestIteration = 934
#
# Training on fold [2/3]
#
# bestTest = 0.1326757342
# bestIteration = 584
#
# 10:	loss: 0.1329622	best: 0.1328640 (8)	total: 1m 50s	remaining: 1m 10s
# Training on fold [0/3]
#
# bestTest = 0.1508776178
# bestIteration = 405
#
# Training on fold [1/3]
#
# bestTest = 0.1528357639
# bestIteration = 320
#
# Training on fold [2/3]
#
# bestTest = 0.1676137155
# bestIteration = 45
#
# 11:	loss: 0.1626912	best: 0.1328640 (8)	total: 2m 16s	remaining: 1m 8s
# Training on fold [0/3]
#
# bestTest = 0.1506361482
# bestIteration = 987
#
# Training on fold [1/3]
#
# bestTest = 0.1293309855
# bestIteration = 685
#
# Training on fold [2/3]
#
# bestTest = 0.1381912283
# bestIteration = 882
#
# 12:	loss: 0.1399205	best: 0.1328640 (8)	total: 2m 53s	remaining: 1m 6s
# Training on fold [0/3]
#
# bestTest = 0.1983404684
# bestIteration = 38
#
# Training on fold [1/3]
#
# bestTest = 0.1592235968
# bestIteration = 18
#
# Training on fold [2/3]
#
# bestTest = 0.165194979
# bestIteration = 93
#
# 13:	loss: 0.1844446	best: 0.1328640 (8)	total: 3m 29s	remaining: 59.9s
# Training on fold [0/3]
#
# bestTest = 0.1521789156
# bestIteration = 983
#
# Training on fold [1/3]
#
# bestTest = 0.1320257037
# bestIteration = 631
#
# Training on fold [2/3]
#
# bestTest = 0.1391315775
# bestIteration = 832
#
# 14:	loss: 0.1416023	best: 0.1328640 (8)	total: 4m 10s	remaining: 50.1s
# Training on fold [0/3]
#
# bestTest = 0.1919328658
# bestIteration = 24
#
# Training on fold [1/3]
#
# bestTest = 0.200011605
# bestIteration = 49
#
# Training on fold [2/3]
#
# bestTest = 0.1550617401
# bestIteration = 37
#
# 15:	loss: 0.1970252	best: 0.1328640 (8)	total: 4m 35s	remaining: 34.5s
# Training on fold [0/3]
#
# bestTest = 0.155343432
# bestIteration = 973
#
# Training on fold [1/3]
#
# bestTest = 0.1332002094
# bestIteration = 475
#
# Training on fold [2/3]
#
# bestTest = 0.137942338
# bestIteration = 999
#
# 16:	loss: 0.1423783	best: 0.1328640 (8)	total: 5m 1s	remaining: 17.7s
# Training on fold [0/3]
#
# bestTest = 0.2151771075
# bestIteration = 53
#
# Training on fold [1/3]
#
# bestTest = 0.2105030735
# bestIteration = 65
#
# Training on fold [2/3]
#
# bestTest = 0.1688079649
# bestIteration = 93
#
# 17:	loss: 0.2093973	best: 0.1328640 (8)	total: 5m 24s	remaining: 0us

# %%
show_results(catboost_cls.predict(test_pool), y_test)
# Out:
# RMSE: 0.1276739987586883
# 0.1276739987586883

# %% [markdown]
# # Kaggle

# %%
test_ds = pd.read_csv('test.csv')
test_ds = prepare_dataset(test_ds)

cat_features = test_ds.select_dtypes(['object']).columns.tolist()
y_pred = catboost_cls.predict(test_ds)

y_pred = np.expm1(y_pred)

# %%
y_pred
# Out:
# array([120995.43352071, 156772.53467243, 180902.51969985, ...,
#        168663.0707533 , 122296.12663951, 230285.94474493])

# %%
my_submission = pd.read_csv('sample_submission.csv')

# %%
my_submission
# Out:
#         Id      SalePrice
# 0     1461  169277.052498
# 1     1462  187758.393989
# 2     1463  183583.683570
# 3     1464  179317.477511
# 4     1465  150730.079977
# ...    ...            ...
# 1454  2915  167081.220949
# 1455  2916  164788.778231
# 1456  2917  219222.423400
# 1457  2918  184924.279659
# 1458  2919  187741.866657
#
# [1459 rows x 2 columns]

# %%
my_submission['SalePrice'] = y_pred

# %%
my_submission
# Out:
#         Id      SalePrice
# 0     1461  120995.433521
# 1     1462  156772.534672
# 2     1463  180902.519700
# 3     1464  195579.875315
# 4     1465  198189.797487
# ...    ...            ...
# 1454  2915   87224.945809
# 1455  2916   85925.232111
# 1456  2917  168663.070753
# 1457  2918  122296.126640
# 1458  2919  230285.944745
#
# [1459 rows x 2 columns]

# %%
my_submission.to_csv('my_submission.csv',index=False)
